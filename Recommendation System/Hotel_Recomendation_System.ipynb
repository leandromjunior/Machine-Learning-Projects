# %% [markdown]
# Vídeo-guia: https://www.youtube.com/watch?v=oTEapSz2m5A&list=PL73l29rZJrFSvqnPLQJ5ucPhvB_uGbUuF&index=9
#
# Dataset infos: https://www.kaggle.com/datasets/jiashenliu/515k-hotel-reviews-data-in-europe

# %%
import pandas as pd
import numpy as np
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from ast import literal_eval
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
df = pd.read_csv("/content/Hotel_Reviews.csv")

# %%
df.head()
# Out:
#                                        Hotel_Address  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
#
#    Additional_Number_of_Scoring Review_Date  Average_Score   Hotel_Name  \
# 0                           194    8/3/2017            7.7  Hotel Arena
# 1                           194    8/3/2017            7.7  Hotel Arena
# 2                           194   7/31/2017            7.7  Hotel Arena
# 3                           194   7/31/2017            7.7  Hotel Arena
# 4                           194   7/24/2017            7.7  Hotel Arena
#
#   Reviewer_Nationality                                    Negative_Review  \
# 0              Russia    I am so angry that i made this post available...
# ...

# %%
df.shape
# Out:
# (515738, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515738 entries, 0 to 515737
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   Hotel_Address                               515738 non-null  object
#  1   Additional_Number_of_Scoring                515738 non-null  int64
#  2   Review_Date                                 515738 non-null  object
#  3   Average_Score                               515738 non-null  float64
#  4   Hotel_Name                                  515738 non-null  object
#  5   Reviewer_Nationality                        515738 non-null  object
#  6   Negative_Review                             515738 non-null  object
#  7   Review_Total_Negative_Word_Counts           515738 non-null  int64
#  8   Total_Number_of_Reviews                     515738 non-null  int64
# ...

# %%
# !pip install pycountry
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 22.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681833 sha256=6099369e71d7e92323909d1662df438ca43b751398d5ccb4359f7bbeee0d9399
#   Stored in directory: /root/.cache/pip/wheels/03/57/cc/290c5252ec97a6d78d36479a3c5e5ecc76318afcb241ad9dbe
# Successfully built pycountry
# ...

# %%
import pycountry

# %%
# Function to find the Country names in the Hotel_Adress column, those countries are being stored in the countriesList
countriesList = []
def findCountryName(data_column):
  for i in data_column:
    for j in pycountry.countries:
      if j.name in i:
        countriesList.append(j.name)

# %%
# calling the function
findCountryName(df.Hotel_Address)

# %%
# Check the unique values from the Hotel_adress column
unique_list = pd.Series(countriesList).drop_duplicates().tolist()

for x in unique_list:
    print(x)
# Out:
# Netherlands
# United Kingdom
# France
# Mexico
# Spain
# Italy
# Austria
# Nicaragua
# Palau
# Panama
# Tunisia

# %% [markdown]
# Substituir nomes de países na coluna Hotel_Adress por suas devidas abreviações (replace)

# %%
df['Hotel_Address'] = df['Hotel_Address'].str.replace("Netherlands", "NL")
df['Hotel_Address'] = df['Hotel_Address'].str.replace("United Kingdom", "UK")
df['Hotel_Address'] = df['Hotel_Address'].str.replace("France", "FR")
df['Hotel_Address'] = df['Hotel_Address'].str.replace("Mexico", "MX")
df['Hotel_Address'] = df['Hotel_Address'].str.replace("Spain", "ES")
df['Hotel_Address'] = df['Hotel_Address'].str.replace("Italy", "IT")
df['Hotel_Address'] = df['Hotel_Address'].str.replace("Austria", "AT")
df['Hotel_Address'] = df['Hotel_Address'].str.replace("Nicaragua", "NI")
df['Hotel_Address'] = df['Hotel_Address'].str.replace("Palau", "PW")
df['Hotel_Address'] = df['Hotel_Address'].str.replace("Panama", "PA")
df['Hotel_Address'] = df['Hotel_Address'].str.replace("Tunisia", "TN")

# %%
# Getting the countries sail and inserting in a new column
df["Countries"] = df.Hotel_Address.apply(lambda x: x.split(' ')[-1])

# %%
df.tail()
# Out:
#                                             Hotel_Address  \
# 515733  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515734  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515735  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515736  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515737  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 515733                           168   8/30/2015            8.1
# 515734                           168   8/22/2015            8.1
# 515735                           168   8/19/2015            8.1
# 515736                           168   8/17/2015            8.1
# 515737                           168    8/9/2015            8.1
#
#                    Hotel_Name Reviewer_Nationality  \
# 515733  Atlantis Hotel Vienna              Kuwait
# 515734  Atlantis Hotel Vienna             Estonia
# 515735  Atlantis Hotel Vienna               Egypt
# ...

# %%
new_df = df[['Hotel_Address', 'Average_Score', 'Hotel_Name', 'Tags', 'Countries']]

# %%
new_df.head()
# Out:
#                                       Hotel_Address  Average_Score  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
#
#     Hotel_Name                                               Tags Countries
# 0  Hotel Arena  [' Leisure trip ', ' Couple ', ' Duplex Double...        NL
# 1  Hotel Arena  [' Leisure trip ', ' Couple ', ' Duplex Double...        NL
# 2  Hotel Arena  [' Leisure trip ', ' Family with young childre...        NL
# 3  Hotel Arena  [' Leisure trip ', ' Solo traveler ', ' Duplex...        NL
# 4  Hotel Arena  [' Leisure trip ', ' Couple ', ' Suite ', ' St...        NL

# %%
# Creating a function to convert the strings of list into a normal list/series (removing the punctuation in general)
def remove_punctuation(col):
  col = col[0]
  if(type(col) != list):
    return "".join(literal_eval(col))
  else:
    return col

# %%
# Applying the function to the Tags column and getting rid of its commas and apostrophes
new_df['Tags'] = new_df[['Tags']].apply(remove_punctuation, axis=1)
# Out:
# <ipython-input-29-49f46d41788e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Tags'] = new_df[['Tags']].apply(remove_punctuation, axis=1)

# %%
new_df.head()
# Out:
#                                       Hotel_Address  Average_Score  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
#
#     Hotel_Name                                               Tags Countries
# 0  Hotel Arena   Leisure trip  Couple  Duplex Double Room  Sta...        NL
# 1  Hotel Arena   Leisure trip  Couple  Duplex Double Room  Sta...        NL
# 2  Hotel Arena   Leisure trip  Family with young children  Dup...        NL
# 3  Hotel Arena   Leisure trip  Solo traveler  Duplex Double Ro...        NL
# 4  Hotel Arena   Leisure trip  Couple  Suite  Stayed 2 nights ...        NL

# %%
new_df['Tags'] = new_df['Tags'].str.lower()
new_df['Countries'] = new_df['Countries'].str.lower()
# Out:
# <ipython-input-31-403be02bbe41>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Tags'] = new_df['Tags'].str.lower()
# <ipython-input-31-403be02bbe41>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Countries'] = new_df['Countries'].str.lower()

# %%
def recommender(countrySail, keywords):
  keywords = keywords.lower()
  # Transforming the sentences into words
  word_tokenize(keywords)

  stop_words = stopwords.words('english')

  lemm = WordNetLemmatizer()

  filtered = {word for word in keywords if not word in stop_words}
  filtered_set = set()
  for fs in filtered:
    filtered_set.add(lemm.lemmatize(fs))

  # location
  country = new_df[new_df['Countries'] == countrySail.lower()]
  country = country.set_index(np.arange(country.shape[0]))

  list1 = []
  list2 = []
  cosineList = []

  for i in range(country.shape[0]):
    temp_token = word_tokenize(country['Tags'][i])
    temp_set = [word for word in temp_token if not word in stop_words]
    temp2_set = set()

    for s in temp_set:
      temp2_set.add(lemm.lemmatize(s))

    vector = temp2_set.intersection(filtered_set)
    cosineList.append(len(vector))

  # Applying cosine similarity
  country['similarity'] = cosineList
  country = country.sort_values(by='similarity', ascending=False)
  country.drop_duplicates(subset="Hotel_Name", keep="first", inplace=True)
  country.sort_values('Average_Score', ascending=False, inplace=True)
  country.reset_index(inplace=True)

  return country[['Hotel_Name', 'Average_Score', 'Hotel_Address']].head(10)

# %%
recommender('NL', 'Business trip Couple 2 nights')
# Out:
#                                     Hotel_Name  Average_Score  \
# 0                    Waldorf Astoria Amsterdam            9.5
# 1        Pillows Anna van den Vondel Amsterdam            9.4
# 2                                    The Toren            9.4
# 3                              Ambassade Hotel            9.3
# 4                         The Hoxton Amsterdam            9.3
# 5                      Luxury Suites Amsterdam            9.3
# 6                                  Canal House            9.3
# 7  Andaz Amsterdam Prinsengracht A Hyatt Hotel            9.3
# 8                         Conservatorium Hotel            9.2
# 9            Banks Mansion All Inclusive Hotel            9.2
#
#                                        Hotel_Address
# 0  Herengracht 542 556 Amsterdam City Center 1017...
# 1  Anna van den Vondelstraat 6 Oud West 1054 GZ A...
# 2  Keizersgracht 164 Amsterdam City Center 1015 C...
# 3  Herengracht 341 Amsterdam City Center 1016 AZ ...
# ...
